# %% [markdown]
# # 🧬 DigPatho: Generación Sintética en Google Colab
#
# Este notebook permite ejecutar la interfaz web de **Streamlit** para el generador sintético utilizando una **GPU gratuita** en la nube de Google Colab. Esto permite que cualquier persona sin hardware potente pueda usar la herramienta.
#
# ### Instrucciones:
# 1. En el menú superior de Colab, ve a **Entorno de ejecución > Cambiar tipo de entorno de ejecución** y asegúrate de seleccionar **GPU** (T4 o superior).
# 2. Ejecuta la **Celda 1** para clonar el proyecto e instalar dependencias.
# 3. Ejecuta la **Celda 2** para iniciar la aplicación en segundo plano.
# 4. Ejecuta la **Celda 3** para obtener el link de acceso a la interfaz web.

# %%
#@title 1. Clonar Repositorio e Instalar Dependencias

# Reemplazar por la URL real de tu repositorio si la subes a GitHub:
GIT_REPO_URL = "https://github.com/tu-usuario/digital-pathologies.git"

import os
# !git clone {GIT_REPO_URL} || echo "El repositorio ya está clonado o la URL no es válida."

# Ajustar directorio de trabajo según la clonación
repo_name = os.path.basename(GIT_REPO_URL).replace(".git", "")
if os.path.exists(repo_name):
    # %cd {repo_name}/generador
else:
    print("ADVERTENCIA: No se pudo ingresar a la carpeta del repositorio. Asegúrate de estar en el directorio correcto.")

# Instalar las librerías del proyecto
# !pip install -r requirements.txt

# Instalar localtunnel para exponer el puerto web al público
# !npm install -g localtunnel

# %%
#@title 2. Iniciar Servidor Web Streamlit

# Correr Streamlit de fondo redireccionando logs a un archivo temporal
# !streamlit run scripts/app.py &>/dev/null &

# %%
#@title 3. Obtener Dirección IP y Link de Acceso

print("======================================================================")
print("COPIA ESTA DIRECCIÓN IP (la vas a necesitar para ingresar al link):")
print("======================================================================")
# !curl ipv4.icanhazip.com
print("======================================================================\n")

print("HACE CLIC EN EL SIGUIENTE LINK PARA ABRIR LA INTERFAZ DE DIGPATHO:")
print("(Cuando cargue, pega la IP de arriba en 'Endpoint IP' y dale a Submit)")
# !npx localtunnel --port 8501
